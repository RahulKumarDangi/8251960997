# %% [markdown]
# <a href="https://colab.research.google.com/github/8251960997/8251960997/blob/main/Applied_statistics_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀

# %% [markdown]
# # Github:

# %% [markdown]
# Github link:

# %% [markdown]
# # Task 1 - Basic Cleanup:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/Superstore Marketing Data - Sheet1 (1).csv')

print(df.info())

df = df.fillna(df.mean())

# Save cleaned dataset
df.to_csv('cleaned_dataset.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
#shape of dataset
df.shape
# Out:
# (2240, 22)

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25037.797168     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35538.750000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51741.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68289.750000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
#check null values,no null values in this dataset
df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
# Check for missing values
missing_values = df.isnull().sum()

# Handle missing values
df.fillna(df.mean(), inplace=True)
df['Education'].fillna(df['Education'].mode()[0], inplace=True)
# Out:
# <ipython-input-10-1a11e1377af8>:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)  # mean imputation for numerical variables

# %%
# Check data types
data_types = df.dtypes

# %% [markdown]
# # Task 2 - Descriptive Statistics 📊

# %%
# Calculate mean, median, and mode for key variables
central_tendency = df[['Income', 'NumDealsPurchases']].agg(['mean', 'median', lambda x: x.mode().iloc[0]])

# %%
# Calculate variance and standard deviation for key variables
dispersion = df[['Income', 'NumDealsPurchases']].agg(['var', 'std'])

# %%
# identifying outliers using z-score
from scipy import stats

z_scores_income = stats.zscore(df['Income'])
outliers_income = df[(z_scores_income < -3) | (z_scores_income > 3)]

z_scores_deals = stats.zscore(df['NumDealsPurchases'])
outliers_deals = df[(z_scores_deals < -3) | (z_scores_deals > 3)]

# %% [markdown]
# Income visualization

# %%
#boxplot for income
plt.figure(figsize=(8, 6))
plt.boxplot(df['Income'], vert=False)
plt.title('Boxplot of Income')
plt.xlabel('Income')
plt.show()

# %%
#removing outliers
filtered_entries = ((z_scores_income > -3) & (z_scores_income < 3))
df_cleaned = df[filtered_entries]

# %% [markdown]
# the distribution of customer ages

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Year_Birth'], bins=20, kde=True, color='skyblue')
plt.title('Age Distribution of Customers')
plt.xlabel('Year of Birth')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# the number of web visits vary across different income levels

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Income'], df['NumWebVisitsMonth'], alpha=0.5)
plt.title('Income vs Number of Web Visits')
plt.xlabel('Income')
plt.ylabel('Number of Web Visits')
plt.show()

# %% [markdown]
# # Task 3 - Probability Distributions 🎲

# %%
# Fit a normal distribution to 'Income'
from scipy.stats import norm

mu, std = norm.fit(df['Income'])

# %%
# Calculate probabilities for a Binomial distribution
from scipy.stats import binom

n = 10
p = 0.5
binom_prob = binom.pmf(5, n, p)

# %% [markdown]
# Distribution of Income with fitted Distribution

# %%
from scipy.stats import norm

# Plot the distribution of 'Income'
plt.figure(figsize=(10, 6))
sns.histplot(df['Income'], kde=True, color='skyblue', label='Income Distribution')

mu, std = norm.fit(df['Income'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Fitted Normal Distribution')

plt.title('Distribution of Income with Fitted Normal Distribution')
plt.xlabel('Income')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# Probability of Successes in Binomial Distribution

# %%
n = 10  # number of trials
p = 0.5  # probability of success
successes = np.arange(0, n+1)
probabilities = binom.pmf(successes, n, p)

plt.figure(figsize=(10, 6))
plt.bar(successes, probabilities, color='skyblue')
plt.title('Probability Distribution for Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(successes)
plt.show()

# %% [markdown]
# # Task 4: Insights and Customer Segmentation 📈

# %%
# Example: Scatter plot of 'Income' vs 'MntWines' (spending on wines)
plt.figure(figsize=(8, 6))
plt.scatter(df['Income'], df['MntWines'], alpha=0.5)
plt.title('Income vs Spending on Wines')
plt.xlabel('Income')
plt.ylabel('Spending on Wines')
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()
# Out:
# <ipython-input-26-619f0e6abd1e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Example: Select 'Income' and 'NumDealsPurchases' for segmentation
X = df[['Income', 'NumDealsPurchases']]

# %%
# Example: Perform K-means clustering
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
df['Cluster'] = kmeans.fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Customer Segmentation based on income and number of deals purchased

# %%
# Example: Visualize clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Income'], df['NumDealsPurchases'], c=df['Cluster'], cmap='viridis', alpha=0.5)
plt.title('Customer Segmentation based on Income and Number of Deals Purchased')
plt.xlabel('Income')
plt.ylabel('Number of Deals Purchased')
plt.show()

# %% [markdown]
# Customer Segmentation based on income and spending on Wines

# %%
# Visualize clusters based on 'Income' and 'MntWines'
plt.figure(figsize=(8, 6))
plt.scatter(df['Income'], df['MntWines'], c=df['Cluster'], cmap='viridis', alpha=0.5)
plt.title('Customer Segmentation based on Income and Spending on Wines')
plt.xlabel('Income')
plt.ylabel('Spending on Wines')
plt.show()

# %% [markdown]
# # Task 5: Conclusion and Recommendations

# %% [markdown]
# Income vs Spending on Wines by Customer Segment

# %%
# Example: Visualize relationship between 'Income' and 'MntWines' for different clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Income', y='MntWines', hue='Cluster', palette='viridis', alpha=0.7)
plt.title('Income vs Spending on Wines by Customer Segment')
plt.xlabel('Income')
plt.ylabel('Spending on Wines')
plt.legend(title='Customer Segment')
plt.show()

# %% [markdown]
# Distribution of Income by Customer Segment

# %%
# Example: Visualize distribution of 'Income' within each cluster
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Cluster', y='Income', palette='viridis')
plt.title('Distribution of Income by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Income')
plt.show()
# Out:
# <ipython-input-32-56651012d38e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='Income', palette='viridis')

# %% [markdown]
# Education Level Distribution

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Education', palette='muted')
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-33-a1b63488bcb4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Education', palette='muted')

# %% [markdown]
# Spending on Different Product Categories

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[['MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds']], palette='pastel')
plt.title('Spending on Different Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Spending')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The dataset contains information on various customer demographics such as income, education level, and marital status, as well as their spending habits across different product categories.
#
# Clustering analysis identifies distinct customer segments based on similarities in income and spending behaviors, allowing for targeted marketing strategies.
#
# Probability distributions such as the Normal distribution and Binomial distribution are fitted to relevant variables to assess their characteristics and calculate probabilities.
#
# The superstore marketing dataset provides valuable insights into customer demographics, spending habits, and relationships between variables.
#
# visualize of this project by different different graphs.In the education level distribution Graduate customers are more.
